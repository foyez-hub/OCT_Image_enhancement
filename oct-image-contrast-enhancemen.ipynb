# %%
import math

import cv2
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Markdown
from glob2 import glob

PATH = '/kaggle/input/octoutput/Denoised/output0/RawDataQA (1)'

# %%
# Gaussian Function:
def G(x, mean, std):
    return np.exp(-0.5*np.square((x-mean)/std))

# Membership Functions:
def ExtremelyDark(x, M):
    return G(x, -50, M/6)

def VeryDark(x, M):
    return G(x, 0, M/6)

def Dark(x, M):
    return G(x, M/2, M/6)

def SlightlyDark(x, M):
    return G(x, 5*M/6, M/6)

def SlightlyBright(x, M):
    return G(x, M+(255-M)/6, (255-M)/6)

def Bright(x, M):
    return G(x, M+(255-M)/2, (255-M)/6)

def VeryBright(x, M):
    return G(x, 255, (255-M)/6)

def ExtremelyBright(x, M):
    return G(x, 305, (255-M)/6)

# %%
for M in (128, 64, 192):
    x = np.arange(-50, 306)
    
    ED = ExtremelyDark(x, M)
    VD = VeryDark(x, M)
    Da = Dark(x, M)
    SD = SlightlyDark(x, M)
    SB = SlightlyBright(x, M)
    Br = Bright(x, M)
    VB = VeryBright(x, M)
    EB = ExtremelyBright(x, M)

    plt.figure(figsize=(20,5))
    plt.plot(x, ED, 'k-.',label='ED', linewidth=1)
    plt.plot(x, VD, 'k-',label='VD', linewidth=2)
    plt.plot(x, Da, 'g-',label='Da', linewidth=2)
    plt.plot(x, SD, 'b-',label='SD', linewidth=2)
    plt.plot(x, SB, 'r-',label='SB', linewidth=2)
    plt.plot(x, Br, 'c-',label='Br', linewidth=2)
    plt.plot(x, VB, 'y-',label='VB', linewidth=2)
    plt.plot(x, EB, 'y-.',label='EB', linewidth=1)
    plt.plot((M, M), (0, 1), 'm--', label='M', linewidth=2)
    plt.plot((0, 0), (0, 1), 'k--', label='MinIntensity', linewidth=2)
    plt.plot((255, 255), (0, 1), 'k--', label='MaxIntensity', linewidth=2)
    plt.legend()
    plt.xlim(-50, 305)
    plt.ylim(0.0, 1.01)
    plt.xlabel('Pixel intensity')
    plt.ylabel('Degree of membership')
    plt.title(f'M={M}')
    plt.show()

# %% [markdown]
# ### 3. Rule Set
# - IF input is VeryDark THEN output is ExtremelyDark
# - IF input is Dark THEN output is VeryDark
# - IF input is SlightlyDark THEN output is Dark
# - IF input is SlightlyBright THEN output is Bright
# - IF input is Bright THEN output is VeryBright
# - IF input is VeryBright THEN output is ExtremelyBright

# %% [markdown]
# ### 4. Inference and Defuzzication (Mamdani's method)

# %%
def OutputFuzzySet(x, f, M, thres):
    x = np.array(x)
    result = f(x, M)
    result[result > thres] = thres
    return result

def AggregateFuzzySets(fuzzy_sets):
    return np.max(np.stack(fuzzy_sets), axis=0)

def Infer(i, M, get_fuzzy_set=False):
    # Calculate degree of membership for each class
    VD = VeryDark(i, M)
    Da = Dark(i, M)
    SD = SlightlyDark(i, M)
    SB = SlightlyBright(i, M)
    Br = Bright(i, M)
    VB = VeryBright(i, M)
    
    # Fuzzy Inference:
    x = np.arange(-50, 306)
    Inferences = (
        OutputFuzzySet(x, ExtremelyDark, M, VD),
        OutputFuzzySet(x, VeryDark, M, Da),
        OutputFuzzySet(x, Dark, M, SD),
        OutputFuzzySet(x, Bright, M, SB),
        OutputFuzzySet(x, VeryBright, M, Br),
        OutputFuzzySet(x, ExtremelyBright, M, VB)
    )
    
    # Calculate AggregatedFuzzySet:
    fuzzy_output = AggregateFuzzySets(Inferences)
    
    # Calculate crisp value of centroid
    if get_fuzzy_set:
        return np.average(x, weights=fuzzy_output), fuzzy_output
    return np.average(x, weights=fuzzy_output)

# %%
for pixel in (64, 96, 160, 192):
    M = 128
    x = np.arange(-50, 306)
    centroid, output_fuzzy_set = Infer(np.array([pixel]), M, get_fuzzy_set=True)
    plt.figure(figsize=(20,5))
    plt.plot(x, output_fuzzy_set, 'k-',label='FuzzySet', linewidth=2)
    plt.plot((M, M), (0, 1), 'm--', label='M', linewidth=2)
    plt.plot((pixel, pixel), (0, 1), 'g--', label='Input', linewidth=2)
    plt.plot((centroid, centroid), (0, 1), 'r--', label='Output', linewidth=2)
    plt.fill_between(x, np.zeros(356), output_fuzzy_set, color=(.9, .9, .9, .9))
    plt.legend()
    plt.xlim(-50, 305)
    plt.ylim(0.0, 1.01)
    plt.xlabel('Output pixel intensity')
    plt.ylabel('Degree of membership')
    plt.title(f'input_pixel_intensity = {pixel}\nM = {M}')
    plt.show()

# %%
means = (64, 96, 128, 160, 192)
plt.figure(figsize=(25,5))
for i in range(len(means)):
    M = means[i]
    x = np.arange(256)
    # %time y = np.array([Infer(np.array([i]), M) for i in x])
    plt.subplot(1, len(means), i+1)
    plt.plot(x, y, 'r-', label='IO mapping')
    plt.xlim(0, 256)
    plt.ylim(-50, 355)
    plt.xlabel('Input Intensity')
    plt.ylabel('Output Intensity')
    plt.title(f'M = {M}')
plt.show()
# Out:
# CPU times: user 64.2 ms, sys: 1.03 ms, total: 65.2 ms
# Wall time: 64.8 ms
# CPU times: user 66.1 ms, sys: 14 µs, total: 66.1 ms
# Wall time: 66.1 ms
# CPU times: user 63.6 ms, sys: 0 ns, total: 63.6 ms
# Wall time: 63.6 ms
# CPU times: user 61.5 ms, sys: 1.95 ms, total: 63.4 ms
# Wall time: 63 ms
# CPU times: user 62.5 ms, sys: 0 ns, total: 62.5 ms
# Wall time: 62.5 ms

# %% [markdown]
# ## IV. Demonstration

# %%
# Proposed fuzzy method
def FuzzyContrastEnhance(rgb):
    # Convert RGB to LAB
    lab = cv2.cvtColor(rgb, cv2.COLOR_RGB2LAB)
    
    # Get L channel
    l = lab[:, :, 0]
    
    # Calculate M value
    M = np.mean(l)
    if M < 128:
        M = 127 - (127 - M)/2
    else:
        M = 128 + M/2
        
    # Precompute the fuzzy transform
    x = list(range(-50,306))
    FuzzyTransform = dict(zip(x,[Infer(np.array([i]), M) for i in x]))
    
    # Apply the transform to l channel
    u, inv = np.unique(l, return_inverse = True)
    l = np.array([FuzzyTransform[i] for i in u])[inv].reshape(l.shape)
    
    # Min-max scale the output L channel to fit (0, 255):
    Min = np.min(l)
    Max = np.max(l)
    lab[:, :, 0] = (l - Min)/(Max - Min) * 255
    
    # Convert LAB to RGB
    return cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

# Traditional method of histogram equalization
def HE(rgb):
    lab = cv2.cvtColor(rgb, cv2.COLOR_RGB2LAB)
    lab[:, :, 0] = cv2.equalizeHist(lab[:, :, 0])
    return cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

# Contrast Limited Adaptive Histogram Equalization
def CLAHE(rgb):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    lab = cv2.cvtColor(rgb, cv2.COLOR_RGB2LAB)
    lab[:, :, 0] = clahe.apply(lab[:, :, 0])
    return cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

# %% [markdown]
# ### 1. Load sample photos

# %%
data = np.array([cv2.cvtColor(cv2.imread(p), cv2.COLOR_BGR2RGB) for p in glob(f'{PATH}/*')])
data.shape
# Out:
# (52, 300, 300, 3)

# %% [markdown]
# ### 2. Apply FCE on sample photos

# %%
for i in range(min(5, data.shape[0])):
    img = data[i]
    fce = FuzzyContrastEnhance(img)
   
    display(Markdown(f'### <p style="text-align: center;">Sample Photo {i+1}</p>'))
    plt.figure(figsize=(15, 10))
    plt.subplot(2, 2, 1)
    plt.imshow(data[i])
    plt.title('Original Image')
    
    plt.subplot(2, 2, 2)
    plt.imshow(fce)
    plt.title('Fuzzy Contrast Enhance')
    
    
    plt.show()
# Out:
# ### <p style="text-align: center;">Sample Photo 1</p>
# ### <p style="text-align: center;">Sample Photo 2</p>
# ### <p style="text-align: center;">Sample Photo 3</p>
# ### <p style="text-align: center;">Sample Photo 4</p>
# ### <p style="text-align: center;">Sample Photo 5</p>

# %%
import os
import shutil
import cv2
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# Define the path to the input directory
INPUT_PATH = '/kaggle/input/testdenoisefinal/denoised_images'
OUTPUT_PATH = '/kaggle/working/ProcessedImages'

# Define the Infer function
def Infer(value, M):
    # Placeholder implementation
    # Replace this with the actual logic for the Infer function
    return np.clip(value * (255.0 / M), 0, 255)

# Define the fuzzy contrast enhancement function (as given)
def FuzzyContrastEnhance(rgb):
    lab = cv2.cvtColor(rgb, cv2.COLOR_RGB2LAB)
    l = lab[:, :, 0]
    M = np.mean(l)
    if M < 128:
        M = 127 - (127 - M)/2
    else:
        M = 128 + M/2
    x = list(range(-50, 306))
    FuzzyTransform = dict(zip(x, [Infer(np.array([i]), M) for i in x]))
    u, inv = np.unique(l, return_inverse=True)
    l = np.array([FuzzyTransform[i] for i in u])[inv].reshape(l.shape)
    Min = np.min(l)
    Max = np.max(l)
    lab[:, :, 0] = (l - Min) / (Max - Min) * 255
    return cv2.cvtColor(lab, cv2.COLOR_LAB2RGB)

# Ensure the output directory exists
if os.path.exists(OUTPUT_PATH):
    shutil.rmtree(OUTPUT_PATH)
os.makedirs(OUTPUT_PATH)

# Function to process and save images
def process_and_save_images(input_path, output_path):
    for root, dirs, files in os.walk(input_path):
        for file in files:
            if file.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'tif')):
                # Construct the full file path
                file_path = os.path.join(root, file)
                
                # Read the image
                img = cv2.cvtColor(cv2.imread(file_path), cv2.COLOR_BGR2RGB)
                
                # Apply the fuzzy contrast enhancement
                fce = FuzzyContrastEnhance(img)
                
                # Construct the corresponding output directory path
                relative_path = os.path.relpath(root, input_path)
                output_dir = os.path.join(output_path, relative_path)
                if not os.path.exists(output_dir):
                    os.makedirs(output_dir)
                
                # Save the processed image
                output_file_path = os.path.join(output_dir, file)
                cv2.imwrite(output_file_path, cv2.cvtColor(fce, cv2.COLOR_RGB2BGR))
                print(f"Processed and saved: {output_file_path}")

# Process the images
process_and_save_images(INPUT_PATH, OUTPUT_PATH)
# Out:
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(176).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(117).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(180).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(122).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(79).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(162).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(198).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(133).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(111).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(154).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(165).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(123).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(57).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(183).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(16).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(136).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(70).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(99).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(53).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(22).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(1).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(144).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(152).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(90).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(159).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(88).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(181).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(193).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(98).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(107).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(80).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(11).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(155).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(145).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(195).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(166).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(148).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(97).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(184).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(196).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(42).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(19).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(66).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(84).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(100).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(199).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(103).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(121).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(10).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(96).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(114).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(167).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(45).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(69).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(52).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(202).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(3).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(58).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(72).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(89).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(24).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(51).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(50).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(59).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(190).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(76).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(34).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(130).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(143).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(187).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(146).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(7).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(75).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(200).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(173).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(82).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(141).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(126).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(94).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(140).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(9).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(137).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(26).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(86).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(37).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(110).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(179).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(163).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(40).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(73).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(188).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(30).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(149).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(6).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(101).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(128).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(77).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(153).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(15).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(60).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(28).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(171).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(118).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(174).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(197).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(104).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(71).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(201).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(156).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(63).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(134).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(20).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(17).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(115).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(8).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(192).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(139).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(160).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(92).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(157).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(135).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(106).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(124).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(151).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(132).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(191).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(56).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(138).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(87).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(43).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(177).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(12).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(25).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(113).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(119).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(64).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(120).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(169).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(33).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(44).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(2).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(194).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(112).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(85).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(81).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(47).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(150).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(62).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(32).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(131).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(93).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(41).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(14).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(48).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(74).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(91).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(36).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(68).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(21).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(78).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(23).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(102).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(127).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(38).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(168).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(185).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(55).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(5).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(186).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(83).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(13).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(67).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(4).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(203).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(31).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(178).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(105).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(46).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(182).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(161).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(189).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(172).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(95).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(142).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(18).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(35).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(147).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(29).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(27).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(61).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(175).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(116).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(39).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(65).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(109).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(158).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(164).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(129).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(108).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(125).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(170).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(49).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (8)/(54).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(79).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(57).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(16).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(70).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(53).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(22).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(1).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(80).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(11).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(42).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(19).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(66).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(10).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(45).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(69).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(52).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(3).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(58).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(72).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(24).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(51).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(50).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(59).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(76).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(34).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(7).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(75).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(9).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(26).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(37).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(40).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(73).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(30).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(6).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(77).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(15).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(60).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(28).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(71).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(63).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(20).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(17).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(8).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(56).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(43).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(12).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(25).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(64).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(33).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(44).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(2).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(81).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(47).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(62).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(32).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(41).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(14).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(48).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(74).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(36).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(68).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(21).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(78).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(23).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(38).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(55).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(5).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(13).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(67).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(4).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(31).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(46).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(18).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(35).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(29).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(27).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(61).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(39).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(65).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(49).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (16)/(54).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(117).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(122).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(79).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(133).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(111).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(123).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(57).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(16).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(136).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(70).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(99).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(53).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(22).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(1).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(90).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(88).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(98).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(107).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(80).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(11).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(97).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(42).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(19).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(66).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(84).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(100).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(103).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(121).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(10).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(96).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(114).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(45).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(69).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(52).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(3).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(58).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(72).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(89).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(24).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(51).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(50).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(59).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(76).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(34).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(130).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(7).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(75).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(82).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(126).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(94).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(9).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(137).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(26).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(86).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(37).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(110).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(40).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(73).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(30).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(6).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(101).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(128).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(77).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(15).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(60).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(28).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(118).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(104).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(71).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(63).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(134).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(20).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(17).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(115).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(8).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(92).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(135).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(106).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(124).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(132).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(56).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(138).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(87).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(43).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(12).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(25).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(113).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(119).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(64).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(120).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(33).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(44).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(2).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(112).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(85).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(81).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(47).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(62).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(32).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(131).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(93).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(41).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(14).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(48).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(74).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(91).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(36).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(68).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(21).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(78).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(23).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(102).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(127).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(38).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(55).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(5).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(83).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(13).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(67).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(4).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(31).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(105).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(46).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(95).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(18).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(35).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(29).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(27).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(61).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(116).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(39).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(65).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(109).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(129).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(108).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(125).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(49).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (17)/(54).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(176).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(117).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(180).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(122).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(79).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(218).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(162).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(198).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(133).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(213).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(111).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(154).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(165).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(123).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(57).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(183).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(16).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(136).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(70).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(99).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(53).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(22).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(1).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(144).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(152).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(90).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(159).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(88).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(181).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(193).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(98).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(107).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(80).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(11).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(155).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(145).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(195).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(166).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(148).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(97).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(184).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(196).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(42).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(19).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(210).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(66).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(84).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(100).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(199).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(103).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(121).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(10).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(96).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(114).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(167).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(209).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(45).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(69).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(52).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(202).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(3).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(58).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(72).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(89).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(221).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(24).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(51).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(50).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(59).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(190).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(76).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(34).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(130).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(223).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(143).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(187).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(219).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(146).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(7).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(75).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(200).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(173).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(82).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(141).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(126).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(94).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(235).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(140).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(9).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(137).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(26).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(86).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(205).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(37).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(110).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(179).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(163).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(40).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(73).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(188).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(30).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(149).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(6).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(101).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(128).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(236).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(77).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(153).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(15).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(60).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(28).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(171).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(232).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(118).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(174).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(197).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(104).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(71).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(207).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(216).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(201).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(156).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(63).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(134).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(20).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(17).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(230).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(115).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(226).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(8).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(229).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(192).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(139).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(160).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(92).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(157).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(135).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(106).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(124).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(151).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(132).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (12)/(191).tif
# ...
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(68).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(21).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(78).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(23).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(102).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(127).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(38).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(168).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(185).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(55).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(234).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(5).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(186).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(83).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(211).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(13).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(67).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(233).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(222).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(4).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(203).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(31).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(260).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(178).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(105).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(208).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(46).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(182).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(161).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(189).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(172).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(95).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(142).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(18).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(35).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(147).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(29).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(27).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(253).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(256).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(224).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(61).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(175).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(212).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(116).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(250).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(228).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(39).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(243).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(65).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(254).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(109).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(158).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(240).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(164).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(129).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(108).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(125).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(170).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(206).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(49).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(220).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(214).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(54).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(244).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(259).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (2)/(225).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(117).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(122).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(79).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(111).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(57).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(16).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(70).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(99).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(53).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(22).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(1).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(90).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(88).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(98).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(107).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(80).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(11).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(97).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(42).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(19).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(66).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(84).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(100).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(103).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(121).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(10).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(96).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(114).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(45).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(69).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(52).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(3).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(58).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(72).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(89).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(24).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(51).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(50).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(59).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(76).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(34).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(7).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(75).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(82).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(94).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(9).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(26).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(86).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(37).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(110).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(40).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(73).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(30).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(6).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(101).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(77).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(15).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(60).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(28).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(118).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(104).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(71).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(63).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(20).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(17).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(115).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(8).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(92).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(106).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(56).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(87).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(43).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(12).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(25).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(113).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(119).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(64).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(120).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(33).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(44).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(2).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(112).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(85).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(81).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(47).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(62).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(32).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(93).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(41).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(14).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(48).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(74).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(91).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(36).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(68).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(21).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(78).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(23).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(102).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(38).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(55).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(5).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(83).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(13).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(67).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(4).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(31).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(105).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(46).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(95).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(18).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(35).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(29).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(27).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(61).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(116).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(39).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(65).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(109).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(108).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(49).tif
# Processed and saved: /kaggle/working/ProcessedImages/output1/RawDataQA (7)/(54).tif
